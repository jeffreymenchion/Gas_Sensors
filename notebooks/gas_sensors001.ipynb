# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame()

df = pd.read_csv("/Users/jeff/Documents/datasets/air_quality/air+quality/AirQualityUCI_spreadsheet1.csv")
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6         1360       150     11,9
# 1     10/03/2004  19.00.00      2         1292       112      9,4
# 2     10/03/2004  20.00.00    2,2         1402        88      9,0
# 3     10/03/2004  21.00.00    2,2         1376        80      9,2
# 4     10/03/2004  22.00.00    1,6         1272        51      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1         1314      -200     13,5
# 9353  04/04/2005  11.00.00    2,4         1163      -200     11,4
# 9354  04/04/2005  12.00.00    2,4         1142      -200     12,4
# 9355  04/04/2005  13.00.00    2,1         1003      -200      9,5
# 9356  04/04/2005  14.00.00    2,2         1071      -200     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# 1               955      103          1174       92          1559
# 2               939      131          1140      114          1555
# 3               948      172          1092      122          1584
# 4               836      131          1205      116          1490
# ...             ...      ...           ...      ...           ...
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)     T    RH      AH
# 0            1268  13,6  48,9  0,7578
# 1             972  13,3  47,7  0,7255
# 2            1074  11,9  54,0  0,7502
# 3            1203  11,0  60,0  0,7867
# 4            1110  11,2  59,6  0,7888
# ...           ...   ...   ...     ...
# 9352         1729  21,9  29,3  0,7568
# 9353         1269  24,3  23,7  0,7119
# 9354         1092  26,9  18,3  0,6406
# 9355          770  28,3  13,5  0,5139
# 9356          816  28,5  13,1  0,5028
#
# [9357 rows x 15 columns]

# %%
#Formatting some object columns from strings to floats

df.replace(to_replace=',',value='.',regex=True,inplace=True)

for i in 'CO(GT) C6H6(GT) T RH AH'.split():
    df[i] = pd.to_numeric(df[i], errors='coerce')

df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6         1360       150      11.9
# 1     10/03/2004  19.00.00     2.0         1292       112       9.4
# 2     10/03/2004  20.00.00     2.2         1402        88       9.0
# 3     10/03/2004  21.00.00     2.2         1376        80       9.2
# 4     10/03/2004  22.00.00     1.6         1272        51       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1         1314      -200      13.5
# 9353  04/04/2005  11.00.00     2.4         1163      -200      11.4
# 9354  04/04/2005  12.00.00     2.4         1142      -200      12.4
# 9355  04/04/2005  13.00.00     2.1         1003      -200       9.5
# 9356  04/04/2005  14.00.00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# 1               955      103          1174       92          1559
# 2               939      131          1140      114          1555
# 3               948      172          1092      122          1584
# 4               836      131          1205      116          1490
# ...             ...      ...           ...      ...           ...
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)     T    RH      AH
# 0            1268  13.6  48.9  0.7578
# 1             972  13.3  47.7  0.7255
# 2            1074  11.9  54.0  0.7502
# 3            1203  11.0  60.0  0.7867
# 4            1110  11.2  59.6  0.7888
# ...           ...   ...   ...     ...
# 9352         1729  21.9  29.3  0.7568
# 9353         1269  24.3  23.7  0.7119
# 9354         1092  26.9  18.3  0.6406
# 9355          770  28.3  13.5  0.5139
# 9356          816  28.5  13.1  0.5028
#
# [9357 rows x 15 columns]

# %%
sns.set_theme(style="whitegrid")

# %%
sns.boxplot(data=df)
plt.xticks(rotation='vertical');
plt.title('Boxplot of the sensors data')
# Out:
# Text(0.5, 1.0, 'Boxplot of the sensors data')

# %%
#Formatting Date and Time to datetime type
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

df['date'] = pd.to_datetime(df['Date'])
df['Day_of_Week'] = df['date'].dt.day_name()
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0    2004-03-10  18.00.00     2.6         1360       150      11.9
# 1    2004-03-10  19.00.00     2.0         1292       112       9.4
# 2    2004-03-10  20.00.00     2.2         1402        88       9.0
# 3    2004-03-10  21.00.00     2.2         1376        80       9.2
# 4    2004-03-10  22.00.00     1.6         1272        51       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352 2005-04-04  10.00.00     3.1         1314      -200      13.5
# 9353 2005-04-04  11.00.00     2.4         1163      -200      11.4
# 9354 2005-04-04  12.00.00     2.4         1142      -200      12.4
# 9355 2005-04-04  13.00.00     2.1         1003      -200       9.5
# 9356 2005-04-04  14.00.00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# 1               955      103          1174       92          1559
# 2               939      131          1140      114          1555
# 3               948      172          1092      122          1584
# 4               836      131          1205      116          1490
# ...             ...      ...           ...      ...           ...
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)     T    RH      AH       date Day_of_Week
# 0            1268  13.6  48.9  0.7578 2004-03-10   Wednesday
# 1             972  13.3  47.7  0.7255 2004-03-10   Wednesday
# 2            1074  11.9  54.0  0.7502 2004-03-10   Wednesday
# 3            1203  11.0  60.0  0.7867 2004-03-10   Wednesday
# 4            1110  11.2  59.6  0.7888 2004-03-10   Wednesday
# ...           ...   ...   ...     ...        ...         ...
# 9352         1729  21.9  29.3  0.7568 2005-04-04      Monday
# 9353         1269  24.3  23.7  0.7119 2005-04-04      Monday
# 9354         1092  26.9  18.3  0.6406 2005-04-04      Monday
# 9355          770  28.3  13.5  0.5139 2005-04-04      Monday
# 9356          816  28.5  13.1  0.5028 2005-04-04      Monday
#
# [9357 rows x 17 columns]

# %%
#Altering the Dataframe - Aligning the Day_of_Week with Date

df = df[['Date', 'Day_of_Week', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']]
df
# Out:
#            Date Day_of_Week      Time  CO(GT)  PT08.S1(CO)  C6H6(GT)  \
# 0    2004-03-10   Wednesday  18.00.00     2.6         1360      11.9
# 1    2004-03-10   Wednesday  19.00.00     2.0         1292       9.4
# 2    2004-03-10   Wednesday  20.00.00     2.2         1402       9.0
# 3    2004-03-10   Wednesday  21.00.00     2.2         1376       9.2
# 4    2004-03-10   Wednesday  22.00.00     1.6         1272       6.5
# ...         ...         ...       ...     ...          ...       ...
# 9352 2005-04-04      Monday  10.00.00     3.1         1314      13.5
# 9353 2005-04-04      Monday  11.00.00     2.4         1163      11.4
# 9354 2005-04-04      Monday  12.00.00     2.4         1142      12.4
# 9355 2005-04-04      Monday  13.00.00     2.1         1003       9.5
# 9356 2005-04-04      Monday  14.00.00     2.2         1071      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# 1               955      103          1174       92          1559
# 2               939      131          1140      114          1555
# 3               948      172          1092      122          1584
# 4               836      131          1205      116          1490
# ...             ...      ...           ...      ...           ...
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)     T    RH      AH
# 0            1268  13.6  48.9  0.7578
# 1             972  13.3  47.7  0.7255
# 2            1074  11.9  54.0  0.7502
# 3            1203  11.0  60.0  0.7867
# 4            1110  11.2  59.6  0.7888
# ...           ...   ...   ...     ...
# 9352         1729  21.9  29.3  0.7568
# 9353         1269  24.3  23.7  0.7119
# 9354         1092  26.9  18.3  0.6406
# 9355          770  28.3  13.5  0.5139
# 9356          816  28.5  13.1  0.5028
#
# [9357 rows x 15 columns]

# %%
#Correlation Heatmap

df3 = df[['CO(GT)', 'PT08.S1(CO)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']]
sns.heatmap(df3.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix');

# %%
sns.barplot(x='Time', y='PT08.S1(CO)', data=df)
plt.title('Hourly Values of CO')
plt.xticks(rotation='vertical');
